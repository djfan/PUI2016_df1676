# %% [markdown]
# # Download Census Business Data from 1994 to 2014.

# %% [markdown]
# ### Data for 1993 and 2015 are not available.

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 2010 - 2014

# %%
# !for ((y=10; y<=15; y+=1)); do wget ftp://ftp.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2016-11-24 11:25:07--  ftp://ftp.census.gov/econ2010/CBP_CSV/zbp10totals.zip
#            => ‘zbp10totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2010/CBP_CSV ... done.
# ==> SIZE zbp10totals.zip ... 797534
# ==> PASV ... done.    ==> RETR zbp10totals.zip ... done.
# Length: 797534 (779K) (unauthoritative)
#
# zbp10totals.zip     100%[===================>] 778.84K   507KB/s    in 1.5s
#
# 2016-11-24 11:25:09 (507 KB/s) - ‘zbp10totals.zip’ saved [797534]
#
# --2016-11-24 11:25:09--  ftp://ftp.census.gov/econ2011/CBP_CSV/zbp11totals.zip
#            => ‘zbp11totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ...

# %% [markdown]
# ## 2002 - 2009

# %%
# !for ((y=0; y<=9; y+=1)); do wget ftp://ftp.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done
# Out:
# --2016-11-24 10:58:01--  ftp://ftp.census.gov/econ2000/CBP_CSV/zbp00totals.zip
#            => ‘zbp00totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2000/CBP_CSV ...
# No such directory ‘econ2000/CBP_CSV’.
#
# --2016-11-24 10:58:01--  ftp://ftp.census.gov/econ2001/CBP_CSV/zbp01totals.zip
#            => ‘zbp01totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2001/CBP_CSV ...
# No such directory ‘econ2001/CBP_CSV’.
#
# --2016-11-24 10:58:01--  ftp://ftp.census.gov/econ2002/CBP_CSV/zbp02totals.zip
#            => ‘zbp02totals.zip’
# ...

# %% [markdown]
# ## 2000 - 2001

# %%
# !for ((y=0; y<=1; y+=1)); do wget ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done
# Out:
# --2016-11-24 11:24:22--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
#            => ‘zbp00totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp00totals.zip ... 628434
# ==> PASV ... done.    ==> RETR zbp00totals.zip ... done.
# Length: 628434 (614K) (unauthoritative)
#
# zbp00totals.zip     100%[===================>] 613.71K   588KB/s    in 1.0s
#
# 2016-11-24 11:24:24 (588 KB/s) - ‘zbp00totals.zip’ saved [628434]
#
# --2016-11-24 11:24:24--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
#            => ‘zbp01totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# ...

# %% [markdown]
# ## 1994 - 1999

# %%
# !for ((y=93; y<=94; y+=1)); do wget ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done
# !for ((y=95; y<=96; y+=1)); do wget ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done
# !for ((y=97; y<=98; y+=1)); do wget ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done
# !for ((y=99; y<=99; y+=1)); do wget ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2016-11-24 11:38:50--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
#            => ‘zbp93totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp93totals.zip ... done.
#
# ==> PASV ... done.    ==> RETR zbp93totals.zip ...
# No such file ‘zbp93totals.zip’.
#
# --2016-11-24 11:38:51--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
#            => ‘zbp94totals.zip’
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000::9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ...
